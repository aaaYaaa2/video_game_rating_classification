# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sb
from sklearn.preprocessing import StandardScaler 
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.metrics import accuracy_score as acc
from sklearn.tree import DecisionTreeClassifier 
from sklearn.linear_model import PassiveAggressiveClassifier 
from sklearn.linear_model import RidgeClassifier 
from sklearn.neighbors import KNeighborsClassifier

# read data 
video_game_rating_train = pd.read_csv("./data/Video_games_esrb_rating.csv")
video_game_rating_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1895 entries, 0 to 1894
# Data columns (total 34 columns):
# title                       1895 non-null object
# console                     1895 non-null int64
# alcohol_reference           1895 non-null int64
# animated_blood              1895 non-null int64
# blood                       1895 non-null int64
# blood_and_gore              1895 non-null int64
# cartoon_violence            1895 non-null int64
# crude_humor                 1895 non-null int64
# drug_reference              1895 non-null int64
# fantasy_violence            1895 non-null int64
# intense_violence            1895 non-null int64
# language                    1895 non-null int64
# lyrics                      1895 non-null int64
# mature_humor                1895 non-null int64
# mild_blood                  1895 non-null int64
# mild_cartoon_violence       1895 non-null int64
# mild_fantasy_violence       1895 non-null int64
# mild_language               1895 non-null int64
# mild_lyrics                 1895 non-null int64
# mild_suggestive_themes      1895 non-null int64
# mild_violence               1895 non-null int64
# no_descriptors              1895 non-null int64
# nudity                      1895 non-null int64
# partial_nudity              1895 non-null int64
# sexual_content              1895 non-null int64
# sexual_themes               1895 non-null int64
# simulated_gambling          1895 non-null int64
# strong_janguage             1895 non-null int64
# strong_sexual_content       1895 non-null int64
# suggestive_themes           1895 non-null int64
# use_of_alcohol              1895 non-null int64
# use_of_drugs_and_alcohol    1895 non-null int64
# violence                    1895 non-null int64
# esrb_rating                 1895 non-null object
# dtypes: int64(32), object(2)
# memory usage: 503.4+ KB

# %%
# EDA 
# look at the console distribution 
PS4_NUM = len(video_game_rating_train[video_game_rating_train['console'] == 0])
PS4_XBOX_NUM = len(video_game_rating_train[video_game_rating_train['console'] == 1])
labels = ['Play Station 4', 'Play Station 4 and XBOX']
values = [PS4_NUM, PS4_XBOX_NUM]

plt.figure(figsize=(17, 5))
plt.subplot(1,2,1)
plt.pie(values, labels = labels, autopct='%1.2f%%')
plt.title('Pie Chart: Console distribution of Video Games Rating Dataset')
plt.show()

# %%
# rating distribution 
uniqueRatingVals = set(video_game_rating_train['esrb_rating'])
countArr = []
for rate_name in uniqueRatingVals:
    countArr.append(len(video_game_rating_train[video_game_rating_train['esrb_rating'] == rate_name]))
    
plt.figure(figsize=(17, 5))
plt.subplot(1, 2, 1)
plt.bar(list(uniqueRatingVals), countArr, color = 'orange')
plt.title(' Bar graph: Rating Distribution ')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.pie(countArr, labels = list(uniqueRatingVals), autopct='%1.2f%%')
plt.title(' Pie chart: Rating Distribution ')
plt.show()

# %%
# relabel esrb_rating to numbers 
rating_mapping = {
    'E': 0,
    'ET': 1,
    'T': 2,
    'M': 3
}

video_game_rating_train['esrb_rating'] = video_game_rating_train['esrb_rating'].map(rating_mapping)

# %%
'''
    Looking at the dataset, we could see that there are some features that might be correlated 
    with each other. 
    
    For instances: animated_blood, blood, blood_and_gore, mild_blood are all related to blood
    violent type. 
    To detect those correlations, we will plot a correlation map between different features 
'''
plt.figure(figsize = (30, 30))
featuresRequired = video_game_rating_train.columns[2:]
sb.heatmap(video_game_rating_train[featuresRequired].corr(), annot = True)
plt.show()

# %%
'''
There are several features with high correlation 
[intense_violence, blood_and_gore] 0.29
[strong_language, blood] 0.29
[strong_sexual_content, blood_and_gore] 0.34
[strong_language, blood_and_gore] 0.22
[simulated_gambling, crude_humor] 0.32
[strong_secual_content, intense_violence] 0.39
[strong_language, sexual_themes] 0.27
[mild_blood, fantasy_violence] 0.23

most of the correlated feature are blood related features 
'''
featuresRequired = video_game_rating_train.columns[2: -1]
featureVector = np.array(video_game_rating_train[featuresRequired])

stdSc = StandardScaler()
featureVector = stdSc.fit_transform(featureVector)

pca = PCA(n_components=2)
pca.fit(featureVector)
featureVector = pca.transform(featureVector)

dimReducedDataFrame = pd.DataFrame(featureVector)
dimReducedDataFrame['targets'] = video_game_rating_train['esrb_rating'].map({0: 'E', 1: 'ET', 2: 'T', 3: 'M'})
dimReducedDataFrame = dimReducedDataFrame.rename(columns = {0: 'V1', 1: 'V2'})
video_game_rating_train['esrb_rating']

plt.figure(figsize=(10, 10))
sb.scatterplot(data=dimReducedDataFrame, x='V1', y='V2', hue='targets')
plt.grid(True)
plt.show()

# %%
# split the set into training and testing
# remove the first column, title 
video_game_model_dataset = video_game_rating_train.loc[:, 'console':'esrb_rating']
video_game_model_dataset.info()
X_train, X_test, y_train, y_test = train_test_split(
    video_game_model_dataset.values[:,:-1],
    video_game_model_dataset.values[:,-1:],
    test_size=0.25,
    random_state=42
)

y_train = y_train.ravel()
y_test = y_test.ravel()
print('Training Dataset Shape: ', X_train.shape, y_train.shape)
print('Testing Dataset Shape: ', X_test.shape, y_test.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1895 entries, 0 to 1894
# Data columns (total 33 columns):
# console                     1895 non-null int64
# alcohol_reference           1895 non-null int64
# animated_blood              1895 non-null int64
# blood                       1895 non-null int64
# blood_and_gore              1895 non-null int64
# cartoon_violence            1895 non-null int64
# crude_humor                 1895 non-null int64
# drug_reference              1895 non-null int64
# fantasy_violence            1895 non-null int64
# intense_violence            1895 non-null int64
# language                    1895 non-null int64
# lyrics                      1895 non-null int64
# mature_humor                1895 non-null int64
# mild_blood                  1895 non-null int64
# mild_cartoon_violence       1895 non-null int64
# mild_fantasy_violence       1895 non-null int64
# mild_language               1895 non-null int64
# mild_lyrics                 1895 non-null int64
# mild_suggestive_themes      1895 non-null int64
# mild_violence               1895 non-null int64
# no_descriptors              1895 non-null int64
# nudity                      1895 non-null int64
# partial_nudity              1895 non-null int64
# sexual_content              1895 non-null int64
# sexual_themes               1895 non-null int64
# simulated_gambling          1895 non-null int64
# strong_janguage             1895 non-null int64
# strong_sexual_content       1895 non-null int64
# suggestive_themes           1895 non-null int64
# use_of_alcohol              1895 non-null int64
# use_of_drugs_and_alcohol    1895 non-null int64
# violence                    1895 non-null int64
# esrb_rating                 1895 non-null int64
# dtypes: int64(33)
# memory usage: 488.6 KB
# Training Dataset Shape:  (1421, 32) (1421,)
# Testing Dataset Shape:  (474, 32) (474,)

# %%
# 1. Classifier: Random forest 
random_forest_classifier = RandomForestClassifier(n_estimators = 100, n_jobs=-1)
# step forward feature selection 
sfs1 = sfs(
    random_forest_classifier,
    k_features = 20,
    forward=True,
    floating=False,
    verbose=2,
    scoring='accuracy',
    cv=5
)

# Perform SFFS 
sfs1 = sfs1.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:   38.8s finished
#
# [2021-05-15 15:43:21] Features: 1/20 -- score: 0.4736076105757351[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:   40.8s finished
#
# [2021-05-15 15:44:02] Features: 2/20 -- score: 0.5826735853718804[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   41.9s finished
#
# [2021-05-15 15:44:44] Features: 3/20 -- score: 0.6657079318013344[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:   40.9s finished
#
# [2021-05-15 15:45:25] Features: 4/20 -- score: 0.7072399308129478[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:   39.6s finished
#
# [2021-05-15 15:46:04] Features: 5/20 -- score: 0.7431430689399555[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:   34.2s finished
#
# [2021-05-15 15:46:39] Features: 6/20 -- score: 0.761433160365703[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:   32.5s finished
#
# [2021-05-15 15:47:11] Features: 7/20 -- score: 0.777615517667408[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:   31.4s finished
#
# [2021-05-15 15:47:42] Features: 8/20 -- score: 0.7923968371633309[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:   30.5s finished
#
# [2021-05-15 15:48:13] Features: 9/20 -- score: 0.8015418828762046[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:   29.4s finished
#
# [2021-05-15 15:48:42] Features: 10/20 -- score: 0.8071658018285148[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:   27.6s finished
#
# [2021-05-15 15:49:10] Features: 11/20 -- score: 0.8106943414875216[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:   27.2s finished
#
# [2021-05-15 15:49:37] Features: 12/20 -- score: 0.8156263899184582[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   26.1s finished
#
# [2021-05-15 15:50:03] Features: 13/20 -- score: 0.8226735853718804[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:   25.0s finished
#
# [2021-05-15 15:50:28] Features: 14/20 -- score: 0.826192241166296[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:   23.6s finished
#
# [2021-05-15 15:50:52] Features: 15/20 -- score: 0.8325228564368669[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:   22.5s finished
#
# [2021-05-15 15:51:14] Features: 16/20 -- score: 0.8346330615270571[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:   21.3s finished
#
# [2021-05-15 15:51:36] Features: 17/20 -- score: 0.8367383246849517[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   20.0s finished
#
# [2021-05-15 15:51:56] Features: 18/20 -- score: 0.8381443044230293[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:   18.7s finished
#
# [2021-05-15 15:52:14] Features: 19/20 -- score: 0.8451840869780085[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   17.5s finished
#
# [2021-05-15 15:52:32] Features: 20/20 -- score: 0.8465900667160859

# %%
# find the feature 
feat_cols = list(sfs1.k_feature_idx_)
print(feat_cols)
# Out:
# SequentialFeatureSelector(estimator=RandomForestClassifier(n_jobs=-1),
#                           k_features=20, scoring='accuracy', verbose=2)

# %%
# build the full model with selected features 
clf = RandomForestClassifier(n_estimators=100, random_state=42, max_depth=4)
clf.fit(X_train[:, feat_cols], y_train)

y_train_pred = clf.predict(X_train[:, feat_cols])
y_test_pred = clf.predict(X_test[:, feat_cols])
print('Training accuracy on selected features: %.3f' % acc(y_train, y_train_pred))
print('Testing accuracy on selected features: %.3f' % acc(y_test, y_test_pred))
# Out:
# Training accuracy on selected features: 0.780
# Testing accuracy on selected features: 0.766

# %%
# Model 2 Decision Tree Model 
decision_tree_classifier = DecisionTreeClassifier(random_state=50)

# step forward feature selection 
sfs2 = sfs(
    decision_tree_classifier,
    k_features = 20,
    forward=False,
    floating=False,
    verbose=2,
    scoring='accuracy',
    cv=5
)

# Perform SFFS on Decision Tree Model  
sfs2 = sfs2.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:    0.5s finished
#
# [2021-05-16 13:26:10] Features: 31/20 -- score: 0.8430615270570792[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:    0.5s finished
#
# [2021-05-16 13:26:11] Features: 30/20 -- score: 0.846577711885347[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    0.5s finished
#
# [2021-05-16 13:26:11] Features: 29/20 -- score: 0.8515072893501359[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    0.5s finished
#
# [2021-05-16 13:26:11] Features: 28/20 -- score: 0.8550407709414382[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    0.4s finished
#
# [2021-05-16 13:26:12] Features: 27/20 -- score: 0.8550407709414382[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    0.4s finished
#
# [2021-05-16 13:26:12] Features: 26/20 -- score: 0.8592512972572276[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    0.4s finished
#
# [2021-05-16 13:26:13] Features: 25/20 -- score: 0.863484062268347[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    0.4s finished
#
# [2021-05-16 13:26:13] Features: 24/20 -- score: 0.8641808747220162[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    0.3s finished
#
# [2021-05-16 13:26:13] Features: 23/20 -- score: 0.8655917963923894[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    0.3s finished
#
# [2021-05-16 13:26:14] Features: 22/20 -- score: 0.8662960217445022[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.3s finished
#
# [2021-05-16 13:26:14] Features: 21/20 -- score: 0.8648900420064244[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    0.3s finished
#
# [2021-05-16 13:26:14] Features: 20/20 -- score: 0.8641932295527551

# %%
feat_cols_decision_tree = list(sfs2.k_feature_idx_)
print(feat_cols_decision_tree)

dtc = DecisionTreeClassifier(random_state=50)
dtc.fit(X_train[:, feat_cols_decision_tree], y_train)

y_train_pred_decision_tree = dtc.predict(X_train[:, feat_cols_decision_tree])
y_test_pred_decision_tree = dtc.predict(X_test[:, feat_cols_decision_tree])
print('Training accuracy on selected features: %.3f' % acc(y_train, y_train_pred_decision_tree))
print('Testing accuracy on selected features: %.3f' % acc(y_test, y_test_pred_decision_tree))
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9, 10, 13, 16, 18, 19, 24, 25, 26, 27, 28, 29, 31]
# Training accuracy on selected features: 0.899
# Testing accuracy on selected features: 0.854

# %%
# Model 3 Passive Aggressive Classifier
passive_aggressive_classifier = PassiveAggressiveClassifier(random_state=45)
sfs3 = sfs(
    passive_aggressive_classifier,
    k_features = 20,
    forward=True,
    floating=False,
    verbose=2,
    scoring='accuracy',
    cv=5
)

# Perform SFFS on Decision Tree Model  
sfs3 = sfs3.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:    0.6s finished
#
# [2021-05-16 14:49:40] Features: 1/20 -- score: 0.35890289103039286[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:    0.7s finished
#
# [2021-05-16 14:49:41] Features: 2/20 -- score: 0.4904941932295528[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    0.7s finished
#
# [2021-05-16 14:49:41] Features: 3/20 -- score: 0.5518359278477886[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    0.7s finished
#
# [2021-05-16 14:49:42] Features: 4/20 -- score: 0.6157598220904373[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    0.6s finished
#
# [2021-05-16 14:49:43] Features: 5/20 -- score: 0.6383073881887817[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    0.6s finished
#
# [2021-05-16 14:49:43] Features: 6/20 -- score: 0.6622213985668395[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    0.5s finished
#
# [2021-05-16 14:49:44] Features: 7/20 -- score: 0.7177786014331604[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    0.6s finished
#
# [2021-05-16 14:49:44] Features: 8/20 -- score: 0.7473412404250063[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    0.6s finished
#
# [2021-05-16 14:49:45] Features: 9/20 -- score: 0.7579046207066964[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    0.6s finished
#
# [2021-05-16 14:49:46] Features: 10/20 -- score: 0.7536767976278724[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.6s finished
#
# [2021-05-16 14:49:46] Features: 11/20 -- score: 0.7529725722757599[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    0.6s finished
#
# [2021-05-16 14:49:47] Features: 12/20 -- score: 0.747343711391154[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.6s finished
#
# [2021-05-16 14:49:47] Features: 13/20 -- score: 0.7543785520138375[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.5s finished
#
# [2021-05-16 14:49:48] Features: 14/20 -- score: 0.7550852483320977[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    0.5s finished
#
# [2021-05-16 14:49:48] Features: 15/20 -- score: 0.7656510995799357[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    0.5s finished
#
# [2021-05-16 14:49:49] Features: 16/20 -- score: 0.7740894489745491[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.4s finished
#
# [2021-05-16 14:49:49] Features: 17/20 -- score: 0.7677489498393871[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.4s finished
#
# [2021-05-16 14:49:50] Features: 18/20 -- score: 0.7677341240425006[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.4s finished
#
# [2021-05-16 14:49:50] Features: 19/20 -- score: 0.770553496417099[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.4s finished
#
# [2021-05-16 14:49:51] Features: 20/20 -- score: 0.78744749196936

# %%
feat_cols_passive_aggressive = list(sfs3.k_feature_idx_)
print(feat_cols_passive_aggressive)

pac = PassiveAggressiveClassifier(random_state=45)
pac.fit(X_train[:, feat_cols_passive_aggressive], y_train)

y_train_pred_passive_aggressive = pac.predict(X_train[:, feat_cols_passive_aggressive])
y_test_pred_passive_aggressive = pac.predict(X_test[:, feat_cols_passive_aggressive])
print('Training accuracy on selected features: %.3f' % acc(y_train, y_train_pred_passive_aggressive))
print('Testing accuracy on selected features: %.3f' % acc(y_test, y_test_pred_passive_aggressive))
# Out:
# [2, 3, 4, 8, 9, 11, 12, 13, 14, 15, 18, 20, 21, 23, 24, 25, 26, 27, 28, 29]
# Training accuracy on selected features: 0.785
# Testing accuracy on selected features: 0.785

# %%
# Model 4 Ridge Classifier 
ridge_classifier = RidgeClassifier(random_state=45)
sfs4 = sfs(
    ridge_classifier,
    k_features = 20,
    forward=True,
    floating=False,
    verbose=2,
    scoring='accuracy',
    cv=5
)

# Perform SFFS on Decision Tree Model  
sfs4 = sfs4.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:    0.5s finished
#
# [2021-05-16 15:26:48] Features: 1/20 -- score: 0.4736076105757351[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:    0.5s finished
#
# [2021-05-16 15:26:49] Features: 2/20 -- score: 0.5826735853718804[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    0.5s finished
#
# [2021-05-16 15:26:49] Features: 3/20 -- score: 0.6635977267111441[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    0.5s finished
#
# [2021-05-16 15:26:50] Features: 4/20 -- score: 0.7044255003706449[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    0.8s finished
#
# [2021-05-16 15:26:51] Features: 5/20 -- score: 0.7382184334074624[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    0.6s finished
#
# [2021-05-16 15:26:51] Features: 6/20 -- score: 0.7536990363232023[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    0.4s finished
#
# [2021-05-16 15:26:52] Features: 7/20 -- score: 0.7635507783543365[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    0.4s finished
#
# [2021-05-16 15:26:52] Features: 8/20 -- score: 0.7804373610081542[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    0.5s finished
#
# [2021-05-16 15:26:52] Features: 9/20 -- score: 0.789582406721028[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    0.5s finished
#
# [2021-05-16 15:26:53] Features: 10/20 -- score: 0.7916926118112182[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.4s finished
#
# [2021-05-16 15:26:53] Features: 11/20 -- score: 0.7931010625154435[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    0.4s finished
#
# [2021-05-16 15:26:54] Features: 12/20 -- score: 0.7945095132196689[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.4s finished
#
# [2021-05-16 15:26:54] Features: 13/20 -- score: 0.7945095132196689[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.3s finished
#
# [2021-05-16 15:26:55] Features: 14/20 -- score: 0.7945095132196689[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    0.3s finished
#
# [2021-05-16 15:26:55] Features: 15/20 -- score: 0.7945095132196689[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    0.3s finished
#
# [2021-05-16 15:26:55] Features: 16/20 -- score: 0.7930961205831479[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.3s finished
#
# [2021-05-16 15:26:56] Features: 17/20 -- score: 0.7931010625154435[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.3s finished
#
# [2021-05-16 15:26:56] Features: 18/20 -- score: 0.7923968371633309[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.3s finished
#
# [2021-05-16 15:26:56] Features: 19/20 -- score: 0.7923968371633309[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.2s finished
#
# [2021-05-16 15:26:56] Features: 20/20 -- score: 0.7916926118112182

# %%
feat_cols_ridge = list(sfs4.k_feature_idx_)
print(feat_cols_ridge)

pac = RidgeClassifier(random_state=45)
pac.fit(X_train[:, feat_cols_passive_aggressive], y_train)

y_train_pred_passive_aggressive = pac.predict(X_train[:, feat_cols_passive_aggressive])
y_test_pred_passive_aggressive = pac.predict(X_test[:, feat_cols_passive_aggressive])
print('Training accuracy on selected features: %.3f' % acc(y_train, y_train_pred_passive_aggressive))
print('Testing accuracy on selected features: %.3f' % acc(y_test, y_test_pred_passive_aggressive))
# Out:
# [0, 1, 2, 3, 4, 5, 7, 8, 9, 12, 14, 15, 20, 21, 22, 24, 25, 26, 28, 29]
# Training accuracy on selected features: 0.785
# Testing accuracy on selected features: 0.776

# %%
kneighbors_classifier = KNeighborsClassifier(n_neighbors=4)
sfs5 = sfs(
    kneighbors_classifier,
    k_features = 20,
    forward=True,
    floating=False,
    verbose=2,
    scoring='accuracy',
    cv=5
)

# Perform SFFS on Decision Tree Model  
sfs5 = sfs5.fit(X_train, y_train)
